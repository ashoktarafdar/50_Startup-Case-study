# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D://Sem 2//python//Deep Learning//Multiple Regression//for categorical dataset//50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# R&D Spend          50 non-null float64
# Administration     50 non-null float64
# Marketing Spend    50 non-null float64
# State              50 non-null object
# Profit             50 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 2.0+ KB

# %%
df.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
# checking the null values in the data set & print them in an ascending order
df.isnull().sum().sort_values(ascending=False)
# Out:
# Profit             0
# State              0
# Marketing Spend    0
# Administration     0
# R&D Spend          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
#Import Label encoder to convert object 
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['State']= label_encoder.fit_transform(df['State'])

from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['R&D Spend']= label_encoder.fit_transform(df['R&D Spend'])

from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Marketing Spend']= label_encoder.fit_transform(df['Marketing Spend'])

from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Profit']= label_encoder.fit_transform(df['Profit'])

from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Administration']= label_encoder.fit_transform(df['Administration'])

# %%
df.dtypes
# Out:
# R&D Spend          int64
# Administration     int64
# Marketing Spend    int64
# State              int64
# Profit             int64
# dtype: object

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State  Profit
# 0         48              34               47      2      49
# 1         47              41               46      0      48
# 2         46              11               45      1      47
# 3         45              22               44      2      46
# 4         44               6               43      1      45

# %%
X = df.iloc[:, :-1]
X
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 0          48              34               47      2
# 1          47              41               46      0
# 2          46              11               45      1
# 3          45              22               44      2
# 4          44               6               43      1
# 5          42              10               42      2
# 6          43              39               10      0
# 7          41              38               40      1
# 8          39              40               39      2
# 9          40              14               38      0
# 10         36              15               24      1
# 11         35               7               25      0
# 12         33              28               26      1
# 13         32              33               27      0
# 14         38              47               28      1
# 15         37              24               29      2
# ...

# %%
Y = df.iloc[:, 4]
Y
# Out:
# 0     49
# 1     48
# 2     47
# 3     46
# 4     45
# 5     44
# 6     43
# 7     42
# 8     41
# 9     40
# 10    39
# 11    38
# 12    37
# 13    36
# 14    35
# 15    34
# 16    33
# 17    32
# 18    31
# 19    30
# 20    29
# 21    28
# 22    27
# 23    26
# 24    25
# 25    24
# 26    23
# 27    22
# 28    21
# 29    20
# 30    19
# 31    18
# 32    17
# 33    16
# 34    15
# 35    14
# 36    13
# 37    12
# 38    11
# 39    10
# 40     9
# 41     8
# 42     7
# 43     6
# 44     5
# 45     4
# 46     3
# 47     2
# 48     1
# 49     0
# Name: Profit, dtype: int64

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regressor.coef_
# Out:
# array([ 0.96461114,  0.00238432,  0.04688279, -0.38881748])

# %%
print(regressor.intercept_)
# Out:
# 0.8799036408773908

# %%
Y_pred = regressor.predict(X_test)
print(Y_pred)
df = pd.DataFrame(Y_test,Y_pred)
print(df)
# Out:
# [21.28669707 35.83005381 36.37803924  8.92075452 46.99915209 24.28204922
#   5.77398335 15.91748524 25.38914226 44.96424261]
#            Profit
# 21.286697     NaN
# 35.830054     NaN
# 36.378039     NaN
# 8.920755      NaN
# 46.999152     NaN
# 24.282049     NaN
# 5.773983      NaN
# 15.917485     NaN
# 25.389142     NaN
# 44.964243     NaN

# %%
regressor.score(X_test,Y_test)
# Out:
# 0.9702101942668738

# %%
#import statsmodel.api as sm
from statsmodels import api as sm
from sklearn.model_selection import train_test_split

x = sm.add_constant(df)
y = df['Profit']

# %%
#Dividing the data into training and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
#Printing the model summary and checking the p values for significant values
df1 = sm.OLS(Y_train, X_train).fit()
df1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     1791.
# Date:                Tue, 19 Nov 2019   Prob (F-statistic):           7.21e-41
# Time:                        00:22:31   Log-Likelihood:                -83.889
# No. Observations:                  40   AIC:                             175.8
# Df Residuals:                      36   BIC:                             182.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
#Running the vif factor to remove the insignificant values
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = np.append(arr = np.ones((50, 1)).astype(int), values = X, axis = 1)

# %%
x_opt = X[:, [0, 1, 2, 3, 4]]
regressor_OLS = sm.OLS(endog = Y, exog = x_opt).fit()
#df1 = sm.OLS(Y_train, X_train).fit()

# %%
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     580.9
# Date:                Tue, 19 Nov 2019   Prob (F-statistic):           4.30e-38
# Time:                        00:38:01   Log-Likelihood:                -105.33
# No. Observations:                  50   AIC:                             220.7
# Df Residuals:                      45   BIC:                             230.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5157      0.832      1.823      0.075      -0.159       3.191
# ...

# %%
X_opt = X[:, [0, 1,]]
regressor_OLS = sm.OLS(endog = Y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     2328.
# Date:                Tue, 19 Nov 2019   Prob (F-statistic):           2.47e-42
# Time:                        00:40:38   Log-Likelihood:                -106.86
# No. Observations:                  50   AIC:                             217.7
# Df Residuals:                      48   BIC:                             221.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1649      0.567      2.054      0.045       0.025       2.305
# ...

# %%
# We see that only R&D is significant while decinding the price 
# R&D spending will give you the best sense of what a company profit will look like
